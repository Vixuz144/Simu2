# %% [markdown]
# <a href="https://colab.research.google.com/github/Vixuz144/Simu2/blob/main/Act1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# #1.- Demuestre que las siguientes ecuaciones tienen al menos una solución en los intervalos dados.

# %% [markdown]
# $ (a) \quad x - (\ln(x))^x = 0$, en $[4, 5] $

# %%
f = lambda x: x - (np.log(x))**x
a, b = 4, 5
x = np.linspace(a, b, 37)

print(f(a), f(b))

plt.plot(x,(f(x)))
plt.axhline(0, color='k')
plt.show()
# Out:
# 0.3066384226706651 -5.798691578322238

# %% [markdown]
# $ (b) \quad x\cos(x) - 2x^2 + 3x - 1 = 0$, en $[0.2, 0.3]$ y $[1.2, 1.3]$

# %%
f = lambda x: x*np.cos(x) -2*x**2 +3*x -1
x = np.linspace(0,1.5,37)

print(f(0.2), f(0.3))
print(f(1.2), f(1.3))

plt.plot(x,(f(x)))
plt.axhline(0, color='k')
plt.show()
# Out:
# -0.28398668443175157 0.0066009467376817454
# 0.154829305372008 -0.13225152278803654

# %% [markdown]
# #2.- Encuentre los intervalos que contengan las soluciones de las siguientes ecuaciones.

# %% [markdown]
# $(a) \quad x - 3^{-x} = 0$

# %%
f = lambda x: x - 3**-x
lx = np.arange(-3,3.1,0.5)
lf = f(lx)

tabla = pd.DataFrame(np.transpose(lf), index=lx, columns=['f(x)'])
print(tabla)
# Out:
#            f(x)
# -3.0 -30.000000
# -2.5 -18.088457
# -2.0 -11.000000
# -1.5  -6.696152
# -1.0  -4.000000
# -0.5  -2.232051
#  0.0  -1.000000
#  0.5  -0.077350
#  1.0   0.666667
#  1.5   1.307550
#  2.0   1.888889
#  2.5   2.435850
#  3.0   2.962963

# %% [markdown]
# $(b) \quad x^3 - 2x^2 - 4x + 3 = 0$

# %% [markdown]
# #3.- Demuestre que las primeras derivadas de las siguientes funciones se anulan al menos una vez en los intervalos dados.

# %% [markdown]
# $(a) \quad (x - 1) \tan (x) + x \sin (\pi x)$, en $[0, 1]$

# %%
f = lambda x: (x-1)*np.tan(x) + x*np.sin(np.pi * x)
a = np.linspace(0,1,37)

print(f(0), f(1))

plt.plot(a,(f(a)))
plt.axhline(0, color='k')
plt.show()
# Out:
# 0.0 1.2246467991473532e-16

# %% [markdown]
# $(b) \quad (x - 2)(\sin (x)) \ln (x + 2)$, en $[−1, 3]$

# %%
f = lambda x: (x-2)*np.sin(x)*np.log(x+2)
a, b = -1, 3
x = np.linspace(a, b, 37)

print(f(a), f(b))
print(f(0), f(2))

plt.plot(x,(f(x)))
plt.axhline(0, color='k')
plt.show()
# Out:
# 0.0 0.2271238911745561
# -0.0 0.0

# %% [markdown]
# #4.- Encuentre $máx_{a≤x≤b} |f(x)|$ para las siguientes funciones e intervalos.

# %% [markdown]
# $(a) \quad f(x) = \frac{2 - e^{x} + 2x}{3}$, en $[0, 1]$

# %%
f = lambda x: (2-np.exp(x)+2*x)/3
a, b = 0,1
x = np.linspace(a, b, 37)

print(f(a), f(b))
print(f(0), f(2))

plt.plot(x,(f(x)))
plt.axhline(0, color='k')
plt.show()
# Out:
# 0.3333333333333333 0.4272393905136516
# 0.3333333333333333 -0.46301869964355014

# %% [markdown]
# $(b) \quad f(x) = \frac{4x-3}{x^2-2x}$, en $[0.5, 1]$

# %%
f = lambda x: (4*x-3)/(x**2-2*x)
a, b = 0.05,1.25
x = np.linspace(a, b, 37)

print(f(a), f(b))

plt.plot(x,(f(x)))
plt.axhline(0, color='k')
plt.show()
# Out:
# 28.717948717948715 -2.1333333333333333
